# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# ANS = 1] Flask is a micro web framework written in Python. It is classified as a microframework because it does not require particular tools or libraries. It has no database abstraction layer, form validation, or any other components where pre-existing third-party libraries provide common functions.

# %% [markdown]
# ANDVANTAGES OF FLASK
#
# - It is a lightweight framework that offers hassle-free development.
#
# - Provide flexibility to the developer to experiment with their modules or       architecture.
#  - It is suitable for small projects.
#  - Offers a built-in development server and fast debugger.
#  - Easily scalable for the applications.
#  - Support for secure cookies.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# ![screenshot.png](attachment:255c4c5d-6a5b-4645-91d1-574656176fdc.png)

# %% [markdown]
# ![Screenshot (13).png](attachment:5aaba88d-1754-46b6-b95b-958891ea3cf1.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# ANS = App routing is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page like Flask Tutorial in the web application.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# ![Screenshot (33).png](attachment:b5294493-eddc-4c2c-b15e-d207b268711b.png)

# %% [markdown]
# ![Screenshot (20).png](attachment:4658ff33-a24e-4cf1-8650-c2c9afc5de88.png)

# %% [markdown]
# Q5.What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
#  ANS = The url_for() function is used to build a URL to the specific function dynamically. The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL.
